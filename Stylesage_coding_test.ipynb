# %%
import requests
import json
import pandas as pd

# %%
response = requests.get("https://api.artic.edu/api/v1/agents/search")

# %%
response.json()
# Out:
# {'preference': None,
#  'pagination': {'total': 14539,
#   'limit': 10,
#   'offset': 0,
#   'total_pages': 1454,
#   'current_page': 1},
#  'data': [{'_score': 1,
#    'api_model': 'agents',
#    'api_link': 'https://aggregator-data.artic.edu/api/v1/agents/60368',
#    'id': 60368,
#    'title': 'Faith Wilding',
#    'timestamp': '2020-05-18T04:01:24-05:00'},
#   {'_score': 1,
#    'api_model': 'agents',
#    'api_link': 'https://aggregator-data.artic.edu/api/v1/agents/115891',
#    'id': 115891,
#    'title': 'Adam Pendleton',
#    'timestamp': '2020-05-18T04:05:02-05:00'},
#   {'_score': 1,
#    'api_model': 'agents',
#    'api_link': 'https://api.artic.edu/api/v1/agents/1963',
#    'id': 1963,
#    'title': 'Jan Abrahamsz. Beerstraaten',
#    'timestamp': '2021-10-05T03:32:41-05:00'},
#   {'_score': 1,
#    'api_model': 'agents',
#    'api_link': 'https://api.artic.edu/api/v1/agents/1974',
#    'id': 1974,
#    'title': 'Sara Begody',
#    'timestamp': '2021-10-05T03:32:41-05:00'},
#   {'_score': 1,
#    'api_model': 'agents',
#    'api_link': 'https://api.artic.edu/api/v1/agents/1992',
#    'id': 1992,
#    'title': 'Peter Behrens',
#    'timestamp': '2021-10-05T03:32:41-05:00'},
#   {'_score': 1,
#    'api_model': 'agents',
#    'api_link': 'https://api.artic.edu/api/v1/agents/1998',
#    'id': 1998,
#    'title': 'Sadiqi',
#    'timestamp': '2021-10-05T03:32:41-05:00'},
#   {'_score': 1,
#    'api_model': 'agents',
#    'api_link': 'https://api.artic.edu/api/v1/agents/2006',
#    'id': 2006,
#    'title': 'Janice Bell',
#    'timestamp': '2021-10-05T03:32:41-05:00'},
#   {'_score': 1,
#    'api_model': 'agents',
#    'api_link': 'https://api.artic.edu/api/v1/agents/2008',
#    'id': 2008,
#    'title': 'Joseph Bell',
#    'timestamp': '2021-10-05T03:32:41-05:00'},
#   {'_score': 1,
#    'api_model': 'agents',
#    'api_link': 'https://api.artic.edu/api/v1/agents/2009',
#    'id': 2009,
#    'title': 'Larry Bell',
#    'timestamp': '2021-10-05T03:32:41-05:00'},
#   {'_score': 1,
#    'api_model': 'agents',
#    'api_link': 'https://api.artic.edu/api/v1/agents/2013',
#    'id': 2013,
#    'title': 'John Haley Bellamy',
#    'timestamp': '2021-10-05T03:32:41-05:00'}],
#  'info': {'license_text': 'The data in this response is licensed under a Creative Commons Zero (CC0) 1.0 designation and the Terms and Conditions of artic.edu.',
#   'license_links': ['https://creativecommons.org/publicdomain/zero/1.0/',
#    'https://www.artic.edu/terms'],
#   'version': '1.1'}}

# %%
response_artist_1= requests.get("https://api.artic.edu/api/v1/agents/1963")
response_artist_1.status_code
# Out:
# 200

# %%
response_artist_1.json()
# Out:
# {'data': {'id': 1963,
#   'api_model': 'agents',
#   'api_link': 'https://api.artic.edu/api/v1/agents/1963',
#   'title': 'Jan Abrahamsz. Beerstraaten',
#   'sort_title': 'Beerstraaten, Jan Abrahamsz.',
#   'alt_titles': ['Jan A. Beerstraaten', 'Johannes Abrahamsz. Beerstraaten'],
#   'birth_date': 1622,
#   'birth_place': None,
#   'death_date': 1666,
#   'death_place': None,
#   'description': None,
#   'is_licensing_restricted': None,
#   'is_artist': True,
#   'agent_type_title': 'Individual',
#   'agent_type_id': 7,
#   'artwork_ids': [83640],
#   'site_ids': [],
#   'last_updated_source': '1976-09-02T11:20:00-05:00',
#   'last_updated': '2019-05-14T15:19:43-05:00',
#   'timestamp': '2021-10-06T22:12:50-05:00'},
#  'info': {'license_text': 'The data in this response is licensed under a Creative Commons Zero (CC0) 1.0 designation and the Terms and Conditions of artic.edu.',
#   'license_links': ['https://creativecommons.org/publicdomain/zero/1.0/',
#    'https://www.artic.edu/terms'],
#   'version': '1.1'},
#  'config': {'iiif_url': 'https://www.artic.edu/iiif/2',
#   'website_url': 'http://www.artic.edu'}}

# %%
response_artist_2= requests.get("https://api.artic.edu/api/v1/agents/1974")
print(response_artist_2.status_code)
# Out:
# 200

# %%
response_artist_2.json()
# Out:
# {'data': {'id': 1974,
#   'api_model': 'agents',
#   'api_link': 'https://api.artic.edu/api/v1/agents/1974',
#   'title': 'Sara Begody',
#   'sort_title': 'Begody, Sara',
#   'alt_titles': None,
#   'birth_date': None,
#   'birth_place': None,
#   'death_date': None,
#   'death_place': None,
#   'description': None,
#   'is_licensing_restricted': None,
#   'is_artist': True,
#   'agent_type_title': 'Individual',
#   'agent_type_id': 7,
#   'artwork_ids': [61009],
#   'site_ids': [],
#   'last_updated_source': '1976-09-02T11:20:00-05:00',
#   'last_updated': '2019-05-14T15:19:42-05:00',
#   'timestamp': '2021-10-06T22:13:29-05:00'},
#  'info': {'license_text': 'The data in this response is licensed under a Creative Commons Zero (CC0) 1.0 designation and the Terms and Conditions of artic.edu.',
#   'license_links': ['https://creativecommons.org/publicdomain/zero/1.0/',
#    'https://www.artic.edu/terms'],
#   'version': '1.1'},
#  'config': {'iiif_url': 'https://www.artic.edu/iiif/2',
#   'website_url': 'http://www.artic.edu'}}

# %%
response_artist_3= requests.get("https://api.artic.edu/api/v1/agents/1992")
print(response_artist_3.status_code)
# Out:
# 200

# %%
response_artist_3.json()
# Out:
# {'data': {'id': 1992,
#   'api_model': 'agents',
#   'api_link': 'https://api.artic.edu/api/v1/agents/1992',
#   'title': 'Peter Behrens',
#   'sort_title': 'Behrens, Peter',
#   'alt_titles': None,
#   'birth_date': 1868,
#   'birth_place': None,
#   'death_date': 1940,
#   'death_place': None,
#   'description': None,
#   'is_licensing_restricted': None,
#   'is_artist': True,
#   'agent_type_title': 'Individual',
#   'agent_type_id': 7,
#   'artwork_ids': [29114, 121781, 120064, 109475],
#   'site_ids': [],
#   'suggest_autocomplete_all': {'input': ['Peter Behrens', 'Behrens, Peter'],
#    'weight': 2,
#    'contexts': {'groupings': ['title']}},
#   'last_updated_source': '1976-09-02T11:20:00-05:00',
#   'last_updated': '2019-05-14T15:19:42-05:00',
#   'timestamp': '2021-10-06T22:14:03-05:00'},
#  'info': {'license_text': 'The data in this response is licensed under a Creative Commons Zero (CC0) 1.0 designation and the Terms and Conditions of artic.edu.',
#   'license_links': ['https://creativecommons.org/publicdomain/zero/1.0/',
#    'https://www.artic.edu/terms'],
#   'version': '1.1'},
#  'config': {'iiif_url': 'https://www.artic.edu/iiif/2',
#   'website_url': 'http://www.artic.edu'}}

# %%
response_artist_4= requests.get("https://api.artic.edu/api/v1/agents/1998")
print(response_artist_4.status_code)
# Out:
# 200

# %%
response_artist_4.json()
# Out:
# {'data': {'id': 1998,
#   'api_model': 'agents',
#   'api_link': 'https://api.artic.edu/api/v1/agents/1998',
#   'title': 'Sadiqi',
#   'sort_title': 'Sadiqi',
#   'alt_titles': ['Sadiki Bek', 'Sadiq Beg', 'Sadiq Beg Afshar'],
#   'birth_date': 1533,
#   'birth_place': None,
#   'death_date': 1610,
#   'death_place': None,
#   'description': None,
#   'is_licensing_restricted': None,
#   'is_artist': True,
#   'agent_type_title': 'Individual',
#   'agent_type_id': 7,
#   'artwork_ids': [70594],
#   'site_ids': [],
#   'last_updated_source': '1976-09-02T11:20:00-05:00',
#   'last_updated': '2019-05-14T15:19:42-05:00',
#   'timestamp': '2021-10-06T22:14:36-05:00'},
#  'info': {'license_text': 'The data in this response is licensed under a Creative Commons Zero (CC0) 1.0 designation and the Terms and Conditions of artic.edu.',
#   'license_links': ['https://creativecommons.org/publicdomain/zero/1.0/',
#    'https://www.artic.edu/terms'],
#   'version': '1.1'},
#  'config': {'iiif_url': 'https://www.artic.edu/iiif/2',
#   'website_url': 'http://www.artic.edu'}}

# %%
response_artist_5= requests.get("https://api.artic.edu/api/v1/agents/2006")
print(response_artist_5.status_code)
# Out:
# 200

# %%
response_artist_5.json()
# Out:
# {'data': {'id': 2006,
#   'api_model': 'agents',
#   'api_link': 'https://api.artic.edu/api/v1/agents/2006',
#   'title': 'Janice Bell',
#   'sort_title': 'Bell, Janice',
#   'alt_titles': None,
#   'birth_date': None,
#   'birth_place': None,
#   'death_date': None,
#   'death_place': None,
#   'description': None,
#   'is_licensing_restricted': None,
#   'is_artist': True,
#   'agent_type_title': 'Individual',
#   'agent_type_id': 7,
#   'artwork_ids': [140958, 54548],
#   'site_ids': [],
#   'suggest_autocomplete_all': {'input': ['Janice Bell', 'Bell, Janice'],
#    'weight': 2,
#    'contexts': {'groupings': ['title']}},
#   'last_updated_source': '1976-09-02T11:20:00-05:00',
#   'last_updated': '2019-05-14T15:19:42-05:00',
#   'timestamp': '2021-10-06T22:15:10-05:00'},
#  'info': {'license_text': 'The data in this response is licensed under a Creative Commons Zero (CC0) 1.0 designation and the Terms and Conditions of artic.edu.',
#   'license_links': ['https://creativecommons.org/publicdomain/zero/1.0/',
#    'https://www.artic.edu/terms'],
#   'version': '1.1'},
#  'config': {'iiif_url': 'https://www.artic.edu/iiif/2',
#   'website_url': 'http://www.artic.edu'}}

# %%
Jan_Abrahamsz_artwork= requests.get("https://api.artic.edu/api/v1/artworks/83640")
print(Jan_Abrahamsz_artwork.status_code)
# Out:
# 200

# %%
Jan_Abrahamsz_artwork.json()
# Out:
# {'data': {'id': 83640,
#   'api_model': 'artworks',
#   'api_link': 'https://api.artic.edu/api/v1/artworks/83640',
#   'is_boosted': False,
#   'title': 'Gemear Castle',
#   'alt_titles': None,
#   'thumbnail': {'lqip': '...',
#    'width': 3000,
#    'height': 1895,
#    'alt_text': 'A work made of pen and wash on paper.'},
#   'main_reference_number': '1922.1690',
#   'has_not_been_viewed_much': True,
#   'boost_rank': None,
#   'date_start': 1642,
#   'date_end': 1666,
#   'date_display': 'n.d.',
#   'date_qualifier_title': '',
#   'date_qualifier_id': None,
#   'artist_display': 'Jan Abrahamsz. Beerstraaten\nDutch, 1622-1666',
#   'place_of_origin': 'Netherlands',
#   'dimensions': None,
#   'medium_display': 'Pen and wash on paper',
#   'inscriptions': None,
#   'credit_line': 'The Leonora Hall Gurley Memorial Collection',
#   'publication_history': None,
#   'exhibition_history': None,
#   'provenance_text': None,
#   'publishing_verification_level': 'Web Basic',
#   'internal_department_id': 3,
#   'fiscal_year': 1921,
#   'fiscal_year_deaccession': None,
#   'is_public_domain': True,
#   'is_zoomable': True,
#   'max_zoom_window_size': -1,
#   'copyright_notice': None,
#   'has_multimedia_resources': False,
#   'has_educational_resources': False,
#   'colorfulness': 19.975,
#   'color': {'h': 39,
#    'l': 53,
#    's': 17,
#    'percentage': 0.07202169123877308,
#    'population': 323},
#   'latitude': None,
#   'longitude': None,
#   'latlon': None,
#   'is_on_view': False,
#   'on_loan_display': None,
#   'gallery_title': None,
#   'gallery_id': None,
#   'artwork_type_title': None,
#   'artwork_type_id': None,
#   'department_title': 'Prints and Drawings',
#   'department_id': 'PC-13',
#   'artist_id': 1963,
#   'artist_title': 'Jan Abrahamsz. Beerstraaten',
#   'alt_artist_ids': [],
#   'artist_ids': [1963],
#   'artist_titles': ['Jan Abrahamsz. Beerstraaten'],
#   'category_ids': ['PC-13'],
#   'category_titles': ['Prints and Drawings'],
#   'artwork_catalogue_ids': [],
#   'term_titles': ['pen and ink drawings',
#    'paper (fiber product)',
#    'wash',
#    'coating (material)',
#    'drawings (visual works)',
#    'prints and drawing'],
#   'style_id': None,
#   'style_title': None,
#   'alt_style_ids': [],
#   'style_ids': [],
#   'style_titles': [],
#   'classification_id': 'TM-212',
#   'classification_title': 'pen and ink drawings',
#   'alt_classification_ids': ['TM-5', 'TM-4'],
#   'classification_ids': ['TM-212', 'TM-5', 'TM-4'],
#   'classification_titles': ['pen and ink drawings',
#    'drawings (visual works)',
#    'prints and drawing'],
#   'subject_id': None,
#   'alt_subject_ids': [],
#   'subject_ids': [],
#   'subject_titles': [],
#   'material_id': 'TM-2982',
#   'alt_material_ids': ['TM-2399', 'TM-3238'],
#   'material_ids': ['TM-2982', 'TM-2399', 'TM-3238'],
#   'material_titles': ['paper (fiber product)', 'wash', 'coating (material)'],
#   'technique_id': None,
#   'alt_technique_ids': [],
#   'technique_ids': [],
#   'technique_titles': [],
#   'theme_titles': [],
#   'image_id': '42d8ac3c-8cfa-94b3-fdfe-8c30a1cd601b',
#   'alt_image_ids': [],
#   'document_ids': [],
#   'sound_ids': [],
#   'video_ids': [],
#   'text_ids': [],
#   'section_ids': [],
#   'section_titles': [],
#   'site_ids': [],
#   'suggest_autocomplete_all': [{'input': ['1922.1690'],
#     'contexts': {'groupings': ['accession']}},
#    {'input': ['Gemear Castle'],
#     'weight': 1,
#     'contexts': {'groupings': ['title']}}],
#   'last_updated_source': '2021-05-03T18:46:11-05:00',
#   'last_updated': '2021-05-21T11:00:47-05:00',
#   'timestamp': '2021-10-06T22:15:52-05:00'},
#  'info': {'license_text': 'The data in this response is licensed under a Creative Commons Zero (CC0) 1.0 designation and the Terms and Conditions of artic.edu.',
#   'license_links': ['https://creativecommons.org/publicdomain/zero/1.0/',
#    'https://www.artic.edu/terms'],
#   'version': '1.1'},
#  'config': {'iiif_url': 'https://www.artic.edu/iiif/2',
#   'website_url': 'http://www.artic.edu'}}

# %%
Sara_Begody_artwork= requests.get("https://api.artic.edu/api/v1/artworks/61009")
print(Sara_Begody_artwork.status_code)
# Out:
# 200

# %%
Sara_Begody_artwork.json()
# Out:
# {'data': {'id': 61009,
#   'api_model': 'artworks',
#   'api_link': 'https://api.artic.edu/api/v1/artworks/61009',
#   'is_boosted': False,
#   'title': 'Rug or Wall Hanging in the "Two Grey Hills" Style',
#   'alt_titles': None,
#   'thumbnail': {'lqip': '...',
#    'width': 930,
#    'height': 1332,
#    'alt_text': 'A work made of wool, single interlocking tapestry weave; twined selvages, heading and finish terminating in tassels.'},
#   'main_reference_number': '1980.689',
#   'has_not_been_viewed_much': True,
#   'boost_rank': None,
#   'date_start': 1960,
#   'date_end': 1969,
#   'date_display': '1960s',
#   'date_qualifier_title': 'Made',
#   'date_qualifier_id': 4,
#   'artist_display': 'Woven by Sara Begody (active c. 1960s)\nNavajo (Diné)\nUnited States, New Mexico',
#   'place_of_origin': 'New Mexico',
#   'dimensions': '78.3 × 56.5 cm (30 3/4 × 22 1/4 in.)',
#   'medium_display': 'Wool, single interlocking tapestry weave; twined selvages, heading and finish terminating in tassels',
#   'inscriptions': None,
#   'credit_line': 'Gift of Mr. and Mrs. Robert Karr',
#   'publication_history': None,
#   'exhibition_history': None,
#   'provenance_text': None,
#   'publishing_verification_level': 'Web Basic',
#   'internal_department_id': 4,
#   'fiscal_year': 1981,
#   'fiscal_year_deaccession': None,
#   'is_public_domain': False,
#   'is_zoomable': False,
#   'max_zoom_window_size': 843,
#   'copyright_notice': None,
#   'has_multimedia_resources': False,
#   'has_educational_resources': False,
#   'colorfulness': 12.4322,
#   'color': {'h': 238,
#    'l': 48,
#    's': 15,
#    'percentage': 0.011105640191017011,
#    'population': 113},
#   'latitude': None,
#   'longitude': None,
#   'latlon': None,
#   'is_on_view': False,
#   'on_loan_display': None,
#   'gallery_title': None,
#   'gallery_id': None,
#   'artwork_type_title': None,
#   'artwork_type_id': None,
#   'department_title': 'Textiles',
#   'department_id': 'PC-14',
#   'artist_id': 1974,
#   'artist_title': 'Sara Begody',
#   'alt_artist_ids': [],
#   'artist_ids': [1974],
#   'artist_titles': ['Sara Begody'],
#   'category_ids': ['PC-825', 'PC-14'],
#   'category_titles': ['Women artists', 'Textiles'],
#   'artwork_catalogue_ids': [],
#   'term_titles': ['navajo',
#    'tapestry weaving',
#    'wool (textile)',
#    'textile',
#    'weaving - rug',
#    'native american',
#    'americas',
#    'weaving'],
#   'style_id': 'TM-7407',
#   'style_title': 'navajo',
#   'alt_style_ids': ['TM-6983', 'TM-6515'],
#   'style_ids': ['TM-7407', 'TM-6983', 'TM-6515'],
#   'style_titles': ['navajo', 'native american', 'americas'],
#   'classification_id': 'TM-69',
#   'classification_title': 'textile',
#   'alt_classification_ids': ['TM-211', 'TM-159'],
#   'classification_ids': ['TM-69', 'TM-211', 'TM-159'],
#   'classification_titles': ['textile', 'weaving - rug', 'weaving'],
#   'subject_id': None,
#   'alt_subject_ids': [],
#   'subject_ids': [],
#   'subject_titles': [],
#   'material_id': 'TM-2581',
#   'alt_material_ids': [],
#   'material_ids': ['TM-2581'],
#   'material_titles': ['wool (textile)'],
#   'technique_id': 'TM-10470',
#   'alt_technique_ids': [],
#   'technique_ids': ['TM-10470'],
#   'technique_titles': ['tapestry weaving'],
#   'theme_titles': ['Women artists'],
#   'image_id': 'afaa3780-23f0-bd23-7cde-bb45c11e9416',
#   'alt_image_ids': [],
#   'document_ids': [],
#   'sound_ids': [],
#   'video_ids': [],
#   'text_ids': [],
#   'section_ids': [],
#   'section_titles': [],
#   'site_ids': [],
#   'suggest_autocomplete_all': [{'input': ['1980.689'],
#     'contexts': {'groupings': ['accession']}},
#    {'input': ['Rug or Wall Hanging in the "Two Grey Hills" Style'],
#     'weight': 1,
#     'contexts': {'groupings': ['title']}}],
#   'last_updated_source': '2021-05-03T18:46:04-05:00',
#   'last_updated': '2021-05-04T08:35:45-05:00',
#   'timestamp': '2021-10-06T22:16:47-05:00'},
#  'info': {'license_text': 'The data in this response is licensed under a Creative Commons Zero (CC0) 1.0 designation and the Terms and Conditions of artic.edu.',
#   'license_links': ['https://creativecommons.org/publicdomain/zero/1.0/',
#    'https://www.artic.edu/terms'],
#   'version': '1.1'},
#  'config': {'iiif_url': 'https://www.artic.edu/iiif/2',
#   'website_url': 'http://www.artic.edu'}}

# %%
Peter_Behrens_artwork= requests.get("https://api.artic.edu/api/v1/artworks/29114")
print(Peter_Behrens_artwork.status_code)
# Out:
# 200

# %%
Peter_Behrens_artwork.json()
# Out:
# {'data': {'id': 29114,
#   'api_model': 'artworks',
#   'api_link': 'https://api.artic.edu/api/v1/artworks/29114',
#   'is_boosted': False,
#   'title': 'The Kiss',
#   'alt_titles': None,
#   'thumbnail': {'lqip': '...',
#    'width': 2296,
#    'height': 2970,
#    'alt_text': 'A work made of color woodcut on paper.'},
#   'main_reference_number': '1968.187',
#   'has_not_been_viewed_much': True,
#   'boost_rank': None,
#   'date_start': 1886,
#   'date_end': 1940,
#   'date_display': 'n.d.',
#   'date_qualifier_title': "Artist's working dates",
#   'date_qualifier_id': 15,
#   'artist_display': 'Peter Behrens\nGerman, 1866-1940',
#   'place_of_origin': 'Germany',
#   'dimensions': '270 × 215 mm (image); 370 × 280 mm (sheet)',
#   'medium_display': 'Color woodcut on paper',
#   'inscriptions': None,
#   'credit_line': 'Prints and Drawings Purchase Account',
#   'publication_history': None,
#   'exhibition_history': None,
#   'provenance_text': None,
#   'publishing_verification_level': 'Web Basic',
#   'internal_department_id': 3,
#   'fiscal_year': None,
#   'fiscal_year_deaccession': None,
#   'is_public_domain': False,
#   'is_zoomable': False,
#   'max_zoom_window_size': 843,
#   'copyright_notice': None,
#   'has_multimedia_resources': False,
#   'has_educational_resources': False,
#   'colorfulness': 23.117,
#   'color': {'h': 37,
#    'l': 39,
#    's': 29,
#    'percentage': 0.19502214676722496,
#    'population': 1792},
#   'latitude': None,
#   'longitude': None,
#   'latlon': None,
#   'is_on_view': False,
#   'on_loan_display': None,
#   'gallery_title': None,
#   'gallery_id': None,
#   'artwork_type_title': None,
#   'artwork_type_id': None,
#   'department_title': 'Prints and Drawings',
#   'department_id': 'PC-13',
#   'artist_id': 1992,
#   'artist_title': 'Peter Behrens',
#   'alt_artist_ids': [],
#   'artist_ids': [1992],
#   'artist_titles': ['Peter Behrens'],
#   'category_ids': ['PC-13'],
#   'category_titles': ['Prints and Drawings'],
#   'artwork_catalogue_ids': [],
#   'term_titles': ['woodcut',
#    'woodcut (process)',
#    'paper (fiber product)',
#    'printing',
#    'print',
#    'prints and drawing'],
#   'style_id': None,
#   'style_title': None,
#   'alt_style_ids': [],
#   'style_ids': [],
#   'style_titles': [],
#   'classification_id': 'TM-148',
#   'classification_title': 'woodcut',
#   'alt_classification_ids': ['TM-17', 'TM-4'],
#   'classification_ids': ['TM-148', 'TM-17', 'TM-4'],
#   'classification_titles': ['woodcut', 'print', 'prints and drawing'],
#   'subject_id': None,
#   'alt_subject_ids': [],
#   'subject_ids': [],
#   'subject_titles': [],
#   'material_id': 'TM-2982',
#   'alt_material_ids': [],
#   'material_ids': ['TM-2982'],
#   'material_titles': ['paper (fiber product)'],
#   'technique_id': 'TM-3862',
#   'alt_technique_ids': ['TM-3861'],
#   'technique_ids': ['TM-3862', 'TM-3861'],
#   'technique_titles': ['woodcut (process)', 'printing'],
#   'theme_titles': [],
#   'image_id': '6ebaf7f3-9a20-4f4f-22fc-57e1a7ce7abe',
#   'alt_image_ids': [],
#   'document_ids': [],
#   'sound_ids': [],
#   'video_ids': [],
#   'text_ids': [],
#   'section_ids': [],
#   'section_titles': [],
#   'site_ids': [],
#   'suggest_autocomplete_all': [{'input': ['1968.187'],
#     'contexts': {'groupings': ['accession']}},
#    {'input': ['The Kiss'],
#     'weight': 115,
#     'contexts': {'groupings': ['title']}}],
#   'last_updated_source': '2021-05-03T18:45:54-05:00',
#   'last_updated': '2021-05-04T11:27:13-05:00',
#   'timestamp': '2021-10-06T22:17:42-05:00'},
#  'info': {'license_text': 'The data in this response is licensed under a Creative Commons Zero (CC0) 1.0 designation and the Terms and Conditions of artic.edu.',
#   'license_links': ['https://creativecommons.org/publicdomain/zero/1.0/',
#    'https://www.artic.edu/terms'],
#   'version': '1.1'},
#  'config': {'iiif_url': 'https://www.artic.edu/iiif/2',
#   'website_url': 'http://www.artic.edu'}}

# %%
Sadiqi_artwork= requests.get("https://api.artic.edu/api/v1/artworks/70594")
print(Sadiqi_artwork.status_code)
# Out:
# 200

# %%
Sadiqi_artwork.json()
# Out:
# {'data': {'id': 70594,
#   'api_model': 'artworks',
#   'api_link': 'https://api.artic.edu/api/v1/artworks/70594',
#   'is_boosted': False,
#   'title': 'The Lion Tamer',
#   'alt_titles': None,
#   'thumbnail': {'lqip': '...',
#    'width': 3000,
#    'height': 1989,
#    'alt_text': 'A work made of ink and gold on paper.'},
#   'main_reference_number': '1987.360.5',
#   'has_not_been_viewed_much': True,
#   'boost_rank': None,
#   'date_start': 1600,
#   'date_end': 1625,
#   'date_display': 'Safavid dynasty (1501–1722), early 17th century',
#   'date_qualifier_title': 'Made',
#   'date_qualifier_id': 4,
#   'artist_display': 'Iran\nAttributed to Sadiqi Beg (1533-1610)',
#   'place_of_origin': 'Iran',
#   'dimensions': 'Image: 13.8 × 19.6 cm (5 7/16 × 7 3/4 in.); \nPaper: 23.3 × 35.5 cm (9 3/16 × 14 in.)',
#   'medium_display': 'Ink and gold on paper',
#   'inscriptions': None,
#   'credit_line': 'Ann McNear Collection',
#   'publication_history': None,
#   'exhibition_history': None,
#   'provenance_text': None,
#   'publishing_verification_level': 'Web Basic',
#   'internal_department_id': 8,
#   'fiscal_year': 1988,
#   'fiscal_year_deaccession': None,
#   'is_public_domain': True,
#   'is_zoomable': True,
#   'max_zoom_window_size': -1,
#   'copyright_notice': None,
#   'has_multimedia_resources': False,
#   'has_educational_resources': False,
#   'colorfulness': 34.9948,
#   'color': {'h': 38,
#    'l': 55,
#    's': 43,
#    'percentage': 0.3458981361820061,
#    'population': 1630},
#   'latitude': None,
#   'longitude': None,
#   'latlon': None,
#   'is_on_view': False,
#   'on_loan_display': None,
#   'gallery_title': None,
#   'gallery_id': None,
#   'artwork_type_title': None,
#   'artwork_type_id': None,
#   'department_title': 'Arts of Asia',
#   'department_id': 'PC-7',
#   'artist_id': 1998,
#   'artist_title': 'Sadiqi',
#   'alt_artist_ids': [],
#   'artist_ids': [1998],
#   'artist_titles': ['Sadiqi'],
#   'category_ids': ['PC-7'],
#   'category_titles': ['Arts of Asia'],
#   'artwork_catalogue_ids': [],
#   'term_titles': ['miniature painting',
#    'paper (fiber product)',
#    'gold',
#    'ink',
#    'painting',
#    'asian art',
#    'Islamic (culture or style)'],
#   'style_id': None,
#   'style_title': None,
#   'alt_style_ids': ['TM-13482'],
#   'style_ids': ['TM-13482'],
#   'style_titles': ['Islamic (culture or style)'],
#   'classification_id': 'TM-340',
#   'classification_title': 'miniature painting',
#   'alt_classification_ids': ['TM-9', 'TM-26'],
#   'classification_ids': ['TM-340', 'TM-9', 'TM-26'],
#   'classification_titles': ['miniature painting', 'painting', 'asian art'],
#   'subject_id': None,
#   'alt_subject_ids': [],
#   'subject_ids': [],
#   'subject_titles': [],
#   'material_id': 'TM-2982',
#   'alt_material_ids': ['TM-2452', 'TM-2398'],
#   'material_ids': ['TM-2982', 'TM-2452', 'TM-2398'],
#   'material_titles': ['paper (fiber product)', 'gold', 'ink'],
#   'technique_id': None,
#   'alt_technique_ids': [],
#   'technique_ids': [],
#   'technique_titles': [],
#   'theme_titles': [],
#   'image_id': '7858447e-b366-d831-6174-903925be68e4',
#   'alt_image_ids': [],
#   'document_ids': [],
#   'sound_ids': [],
#   'video_ids': [],
#   'text_ids': [],
#   'section_ids': [],
#   'section_titles': [],
#   'site_ids': [],
#   'suggest_autocomplete_all': [{'input': ['1987.360.5'],
#     'contexts': {'groupings': ['accession']}},
#    {'input': ['The Lion Tamer'],
#     'weight': 92,
#     'contexts': {'groupings': ['title']}}],
#   'last_updated_source': '2021-05-03T18:46:07-05:00',
#   'last_updated': '2021-05-21T12:28:15-05:00',
#   'timestamp': '2021-10-06T22:18:16-05:00'},
#  'info': {'license_text': 'The data in this response is licensed under a Creative Commons Zero (CC0) 1.0 designation and the Terms and Conditions of artic.edu.',
#   'license_links': ['https://creativecommons.org/publicdomain/zero/1.0/',
#    'https://www.artic.edu/terms'],
#   'version': '1.1'},
#  'config': {'iiif_url': 'https://www.artic.edu/iiif/2',
#   'website_url': 'http://www.artic.edu'}}

# %%
Janice_Bell_artwork= requests.get("https://api.artic.edu/api/v1/artworks/54548")
print(Janice_Bell_artwork.status_code)
# Out:
# 200

# %%
Janice_Bell_artwork.json()
# Out:
# {'data': {'id': 54548,
#   'api_model': 'artworks',
#   'api_link': 'https://api.artic.edu/api/v1/artworks/54548',
#   'is_boosted': False,
#   'title': 'Untitled',
#   'alt_titles': None,
#   'thumbnail': {'lqip': '...',
#    'width': 3000,
#    'height': 2980,
#    'alt_text': 'A work made of chromogenic print.'},
#   'main_reference_number': '1978.1114.3',
#   'has_not_been_viewed_much': True,
#   'boost_rank': None,
#   'date_start': 1973,
#   'date_end': 1978,
#   'date_display': 'c. 1978',
#   'date_qualifier_title': 'Made',
#   'date_qualifier_id': 4,
#   'artist_display': 'Janice Bell\nAmerican, 20th century',
#   'place_of_origin': 'United States',
#   'dimensions': '21.6 × 21.6 cm',
#   'medium_display': 'Chromogenic print',
#   'inscriptions': None,
#   'credit_line': 'Gift of the School of The Art Institute of Chicago Graduate Students and Faculty',
#   'publication_history': None,
#   'exhibition_history': None,
#   'provenance_text': None,
#   'publishing_verification_level': 'Web Basic',
#   'internal_department_id': 20,
#   'fiscal_year': None,
#   'fiscal_year_deaccession': None,
#   'is_public_domain': False,
#   'is_zoomable': False,
#   'max_zoom_window_size': 843,
#   'copyright_notice': None,
#   'has_multimedia_resources': False,
#   'has_educational_resources': False,
#   'colorfulness': 34.0706,
#   'color': {'h': 64,
#    'l': 30,
#    's': 19,
#    'percentage': 0.03784116331096197,
#    'population': 3383},
#   'latitude': None,
#   'longitude': None,
#   'latlon': None,
#   'is_on_view': False,
#   'on_loan_display': None,
#   'gallery_title': None,
#   'gallery_id': None,
#   'artwork_type_title': None,
#   'artwork_type_id': None,
#   'department_title': 'Photography and Media',
#   'department_id': 'PC-12',
#   'artist_id': 2006,
#   'artist_title': 'Janice Bell',
#   'alt_artist_ids': [],
#   'artist_ids': [2006],
#   'artist_titles': ['Janice Bell'],
#   'category_ids': ['PC-12', 'PC-825', 'PC-827'],
#   'category_titles': ['Photography and Media',
#    'Women artists',
#    'SAIC Alumni and Faculty'],
#   'artwork_catalogue_ids': [],
#   'term_titles': ['chromogenic color print',
#    'photographic process',
#    'photography',
#    'photograph'],
#   'style_id': None,
#   'style_title': None,
#   'alt_style_ids': [],
#   'style_ids': [],
#   'style_titles': [],
#   'classification_id': 'TM-558',
#   'classification_title': 'chromogenic color print',
#   'alt_classification_ids': ['TM-68', 'TM-67', 'TM-240'],
#   'classification_ids': ['TM-558', 'TM-68', 'TM-67', 'TM-240'],
#   'classification_titles': ['chromogenic color print',
#    'photographic process',
#    'photography',
#    'photograph'],
#   'subject_id': None,
#   'alt_subject_ids': [],
#   'subject_ids': [],
#   'subject_titles': [],
#   'material_id': None,
#   'alt_material_ids': [],
#   'material_ids': [],
#   'material_titles': [],
#   'technique_id': None,
#   'alt_technique_ids': [],
#   'technique_ids': [],
#   'technique_titles': [],
#   'theme_titles': ['Women artists', 'SAIC Alumni and Faculty'],
#   'image_id': 'e36730d5-49c4-908d-0f5a-0e89dc99d9dd',
#   'alt_image_ids': [],
#   'document_ids': [],
#   'sound_ids': [],
#   'video_ids': [],
#   'text_ids': [],
#   'section_ids': [],
#   'section_titles': [],
#   'site_ids': [],
#   'suggest_autocomplete_all': [{'input': ['1978.1114.3'],
#     'contexts': {'groupings': ['accession']}},
#    {'input': ['Untitled'],
#     'weight': 24,
#     'contexts': {'groupings': ['title']}}],
#   'last_updated_source': '2021-05-03T18:46:03-05:00',
#   'last_updated': '2021-05-24T15:52:52-05:00',
#   'timestamp': '2021-10-06T22:18:47-05:00'},
#  'info': {'license_text': 'The data in this response is licensed under a Creative Commons Zero (CC0) 1.0 designation and the Terms and Conditions of artic.edu.',
#   'license_links': ['https://creativecommons.org/publicdomain/zero/1.0/',
#    'https://www.artic.edu/terms'],
#   'version': '1.1'},
#  'config': {'iiif_url': 'https://www.artic.edu/iiif/2',
#   'website_url': 'http://www.artic.edu'}}

# %%
lista = [response_artist_1.json(),response_artist_2.json(),response_artist_3.json(),response_artist_4.json(),response_artist_5.json()]

# %%
print(lista)
# Out:
# [{'data': {'id': 1963, 'api_model': 'agents', 'api_link': 'https://api.artic.edu/api/v1/agents/1963', 'title': 'Jan Abrahamsz. Beerstraaten', 'sort_title': 'Beerstraaten, Jan Abrahamsz.', 'alt_titles': ['Jan A. Beerstraaten', 'Johannes Abrahamsz. Beerstraaten'], 'birth_date': 1622, 'birth_place': None, 'death_date': 1666, 'death_place': None, 'description': None, 'is_licensing_restricted': None, 'is_artist': True, 'agent_type_title': 'Individual', 'agent_type_id': 7, 'artwork_ids': [83640], 'site_ids': [], 'last_updated_source': '1976-09-02T11:20:00-05:00', 'last_updated': '2019-05-14T15:19:43-05:00', 'timestamp': '2021-10-06T22:12:50-05:00'}, 'info': {'license_text': 'The data in this response is licensed under a Creative Commons Zero (CC0) 1.0 designation and the Terms and Conditions of artic.edu.', 'license_links': ['https://creativecommons.org/publicdomain/zero/1.0/', 'https://www.artic.edu/terms'], 'version': '1.1'}, 'config': {'iiif_url': 'https://www.artic.edu/iiif/2', 'website_url': 'http://www.artic.edu'}}, {'data': {'id': 1974, 'api_model': 'agents', 'api_link': 'https://api.artic.edu/api/v1/agents/1974', 'title': 'Sara Begody', 'sort_title': 'Begody, Sara', 'alt_titles': None, 'birth_date': None, 'birth_place': None, 'death_date': None, 'death_place': None, 'description': None, 'is_licensing_restricted': None, 'is_artist': True, 'agent_type_title': 'Individual', 'agent_type_id': 7, 'artwork_ids': [61009], 'site_ids': [], 'last_updated_source': '1976-09-02T11:20:00-05:00', 'last_updated': '2019-05-14T15:19:42-05:00', 'timestamp': '2021-10-06T22:13:29-05:00'}, 'info': {'license_text': 'The data in this response is licensed under a Creative Commons Zero (CC0) 1.0 designation and the Terms and Conditions of artic.edu.', 'license_links': ['https://creativecommons.org/publicdomain/zero/1.0/', 'https://www.artic.edu/terms'], 'version': '1.1'}, 'config': {'iiif_url': 'https://www.artic.edu/iiif/2', 'website_url': 'http://www.artic.edu'}}, {'data': {'id': 1992, 'api_model': 'agents', 'api_link': 'https://api.artic.edu/api/v1/agents/1992', 'title': 'Peter Behrens', 'sort_title': 'Behrens, Peter', 'alt_titles': None, 'birth_date': 1868, 'birth_place': None, 'death_date': 1940, 'death_place': None, 'description': None, 'is_licensing_restricted': None, 'is_artist': True, 'agent_type_title': 'Individual', 'agent_type_id': 7, 'artwork_ids': [29114, 121781, 120064, 109475], 'site_ids': [], 'suggest_autocomplete_all': {'input': ['Peter Behrens', 'Behrens, Peter'], 'weight': 2, 'contexts': {'groupings': ['title']}}, 'last_updated_source': '1976-09-02T11:20:00-05:00', 'last_updated': '2019-05-14T15:19:42-05:00', 'timestamp': '2021-10-06T22:14:03-05:00'}, 'info': {'license_text': 'The data in this response is licensed under a Creative Commons Zero (CC0) 1.0 designation and the Terms and Conditions of artic.edu.', 'license_links': ['https://creativecommons.org/publicdomain/zero/1.0/', 'https://www.artic.edu/terms'], 'version': '1.1'}, 'config': {'iiif_url': 'https://www.artic.edu/iiif/2', 'website_url': 'http://www.artic.edu'}}, {'data': {'id': 1998, 'api_model': 'agents', 'api_link': 'https://api.artic.edu/api/v1/agents/1998', 'title': 'Sadiqi', 'sort_title': 'Sadiqi', 'alt_titles': ['Sadiki Bek', 'Sadiq Beg', 'Sadiq Beg Afshar'], 'birth_date': 1533, 'birth_place': None, 'death_date': 1610, 'death_place': None, 'description': None, 'is_licensing_restricted': None, 'is_artist': True, 'agent_type_title': 'Individual', 'agent_type_id': 7, 'artwork_ids': [70594], 'site_ids': [], 'last_updated_source': '1976-09-02T11:20:00-05:00', 'last_updated': '2019-05-14T15:19:42-05:00', 'timestamp': '2021-10-06T22:14:36-05:00'}, 'info': {'license_text': 'The data in this response is licensed under a Creative Commons Zero (CC0) 1.0 designation and the Terms and Conditions of artic.edu.', 'license_links': ['https://creativecommons.org/publicdomain/zero/1.0/', 'https://www.artic.edu/terms'], 'version': '1.1'}, 'config': {'iiif_url': 'https://www.artic.edu ...

# %%
data = pd.DataFrame(lista)
data
# Out:
#                                                 data  \
# 0  {'id': 1963, 'api_model': 'agents', 'api_link'...
# 1  {'id': 1974, 'api_model': 'agents', 'api_link'...
# 2  {'id': 1992, 'api_model': 'agents', 'api_link'...
# 3  {'id': 1998, 'api_model': 'agents', 'api_link'...
# 4  {'id': 2006, 'api_model': 'agents', 'api_link'...
#
#                                                 info  \
# 0  {'license_text': 'The data in this response is...
# 1  {'license_text': 'The data in this response is...
# 2  {'license_text': 'The data in this response is...
# 3  {'license_text': 'The data in this response is...
# 4  {'license_text': 'The data in this response is...
#
#                                               config
# 0  {'iiif_url': 'https://www.artic.edu/iiif/2', '...
# 1  {'iiif_url': 'https://www.artic.edu/iiif/2', '...
# 2  {'iiif_url': 'https://www.artic.edu/iiif/2', '...
# 3  {'iiif_url': 'https://www.artic.edu/iiif/2', '...
# 4  {'iiif_url': 'https://www.artic.edu/iiif/2', '...

# %%
from pandas import json_normalize

# %%
artist_data=json_normalize(lista)
artist_data
# Out:
#    data.id data.api_model                             data.api_link  \
# 0     1963         agents  https://api.artic.edu/api/v1/agents/1963
# 1     1974         agents  https://api.artic.edu/api/v1/agents/1974
# 2     1992         agents  https://api.artic.edu/api/v1/agents/1992
# 3     1998         agents  https://api.artic.edu/api/v1/agents/1998
# 4     2006         agents  https://api.artic.edu/api/v1/agents/2006
#
#                     data.title               data.sort_title  \
# 0  Jan Abrahamsz. Beerstraaten  Beerstraaten, Jan Abrahamsz.
# 1                  Sara Begody                  Begody, Sara
# 2                Peter Behrens                Behrens, Peter
# 3                       Sadiqi                        Sadiqi
# 4                  Janice Bell                  Bell, Janice
#
#                                      data.alt_titles  data.birth_date  \
# 0  [Jan A. Beerstraaten, Johannes Abrahamsz. Beer...           1622.0
# 1                                               None              NaN
# 2                                               None           1868.0
# 3          [Sadiki Bek, Sadiq Beg, Sadiq Beg Afshar]           1533.0
# 4                                               None              NaN
#
#   data.birth_place  data.death_date data.death_place  ...  \
# 0             None           1666.0             None  ...
# 1             None              NaN             None  ...
# 2             None           1940.0             None  ...
# 3             None           1610.0             None  ...
# 4             None              NaN             None  ...
#
#            data.last_updated             data.timestamp  \
# 0  2019-05-14T15:19:43-05:00  2021-10-06T22:12:50-05:00
# 1  2019-05-14T15:19:42-05:00  2021-10-06T22:13:29-05:00
# 2  2019-05-14T15:19:42-05:00  2021-10-06T22:14:03-05:00
# 3  2019-05-14T15:19:42-05:00  2021-10-06T22:14:36-05:00
# 4  2019-05-14T15:19:42-05:00  2021-10-06T22:15:10-05:00
#
#                                    info.license_text  \
# 0  The data in this response is licensed under a ...
# 1  The data in this response is licensed under a ...
# 2  The data in this response is licensed under a ...
# 3  The data in this response is licensed under a ...
# 4  The data in this response is licensed under a ...
#
#                                   info.license_links  info.version  \
# 0  [https://creativecommons.org/publicdomain/zero...           1.1
# 1  [https://creativecommons.org/publicdomain/zero...           1.1
# 2  [https://creativecommons.org/publicdomain/zero...           1.1
# 3  [https://creativecommons.org/publicdomain/zero...           1.1
# 4  [https://creativecommons.org/publicdomain/zero...           1.1
#
#                 config.iiif_url    config.website_url  \
# 0  https://www.artic.edu/iiif/2  http://www.artic.edu
# 1  https://www.artic.edu/iiif/2  http://www.artic.edu
# 2  https://www.artic.edu/iiif/2  http://www.artic.edu
# 3  https://www.artic.edu/iiif/2  http://www.artic.edu
# 4  https://www.artic.edu/iiif/2  http://www.artic.edu
#
#   data.suggest_autocomplete_all.input data.suggest_autocomplete_all.weight  \
# 0                                 NaN                                  NaN
# 1                                 NaN                                  NaN
# 2     [Peter Behrens, Behrens, Peter]                                  2.0
# 3                                 NaN                                  NaN
# 4         [Janice Bell, Bell, Janice]                                  2.0
#
#   data.suggest_autocomplete_all.contexts.groupings
# 0                                              NaN
# 1                                              NaN
# 2                                          [title]
# 3                                              NaN
# 4                                          [title]
#
# [5 rows x 28 columns]

# %%
artist_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 28 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   data.id                                           5 non-null      int64
#  1   data.api_model                                    5 non-null      object
#  2   data.api_link                                     5 non-null      object
#  3   data.title                                        5 non-null      object
#  4   data.sort_title                                   5 non-null      object
#  5   data.alt_titles                                   2 non-null      object
#  6   data.birth_date                                   3 non-null      float64
#  7   data.birth_place                                  0 non-null      object
#  8   data.death_date                                   3 non-null      float64
#  9   data.death_place                                  0 non-null      object
#  10  data.description                                  0 non-null      object
#  11  data.is_licensing_restricted                      0 non-null      object
#  12  data.is_artist                                    5 non-null      bool
#  13  data.agent_type_title                             5 non-null      object
#  14  data.agent_type_id                                5 non-null      int64
#  15  data.artwork_ids                                  5 non-null      object
#  16  data.site_ids                                     5 non-null      object
#  17  data.last_updated_source                          5 non-null      object
#  18  data.last_updated                                 5 non-null      object
#  19  data.timestamp                                    5 non-null      object
#  20  info.license_text                                 5 non-null      object
#  21  info.license_links                                5 non-null      object
#  22  info.version                                      5 non-null      object
#  23  config.iiif_url                                   5 non-null      object
#  24  config.website_url                                5 non-null      object
#  25  data.suggest_autocomplete_all.input               2 non-null      object
#  26  data.suggest_autocomplete_all.weight              2 non-null      float64
#  27  data.suggest_autocomplete_all.contexts.groupings  2 non-null      object
# dtypes: bool(1), float64(3), int64(2), object(22)
# memory usage: 1.2+ KB

# %%
artist_data=artist_data.drop(['data.suggest_autocomplete_all.contexts.groupings'],axis=1)
artist_data=artist_data.drop(['data.suggest_autocomplete_all.weight'],axis=1)
artist_data=artist_data.drop(['data.suggest_autocomplete_all.input'],axis=1)
artist_data=artist_data.drop(['config.website_url'],axis=1)
artist_data=artist_data.drop(['config.iiif_url'],axis=1)
artist_data=artist_data.drop(['info.version'],axis=1)
artist_data=artist_data.drop(['info.license_links'],axis=1)
artist_data=artist_data.drop(['info.license_text'],axis=1)
artist_data=artist_data.drop(['data.timestamp'],axis=1)
artist_data=artist_data.drop(['data.last_updated'],axis=1)
artist_data=artist_data.drop(['data.last_updated_source'],axis=1)
artist_data=artist_data.drop(['data.site_ids'],axis=1)
artist_data=artist_data.drop(['data.is_licensing_restricted'],axis=1)
artist_data=artist_data.drop(['data.description'],axis=1)
artist_data=artist_data.drop(['data.death_place'],axis=1)
artist_data=artist_data.drop(['data.birth_place'],axis=1)
artist_data=artist_data.drop(['data.alt_titles'],axis=1)
artist_data=artist_data.drop(['data.api_link'],axis=1)
artist_data=artist_data.drop(['data.api_model'],axis=1)
artist_data=artist_data.drop(['data.agent_type_id'],axis=1)

# %%
artist_data=artist_data.rename(columns={'data.title': 'artist_title'})
artist_data=artist_data.rename(columns={'data.id': 'artist_id'})
artist_data=artist_data.rename(columns={'data.artwork_ids': 'number_of_artworks_and_ids'})

# %%
artist_data
# Out:
#    artist_id                 artist_title               data.sort_title  \
# 0       1963  Jan Abrahamsz. Beerstraaten  Beerstraaten, Jan Abrahamsz.
# 1       1974                  Sara Begody                  Begody, Sara
# 2       1992                Peter Behrens                Behrens, Peter
# 3       1998                       Sadiqi                        Sadiqi
# 4       2006                  Janice Bell                  Bell, Janice
#
#    data.birth_date  data.death_date  data.is_artist data.agent_type_title  \
# 0           1622.0           1666.0            True            Individual
# 1              NaN              NaN            True            Individual
# 2           1868.0           1940.0            True            Individual
# 3           1533.0           1610.0            True            Individual
# 4              NaN              NaN            True            Individual
#
#         number_of_artworks_and_ids
# 0                          [83640]
# 1                          [61009]
# 2  [29114, 121781, 120064, 109475]
# 3                          [70594]
# 4                  [140958, 54548]

# %%
lista_2=[Jan_Abrahamsz_artwork.json(),Sara_Begody_artwork.json(),Peter_Behrens_artwork.json(),Sadiqi_artwork.json(),Janice_Bell_artwork.json()]
print(lista)
# Out:
# [{'data': {'id': 1963, 'api_model': 'agents', 'api_link': 'https://api.artic.edu/api/v1/agents/1963', 'title': 'Jan Abrahamsz. Beerstraaten', 'sort_title': 'Beerstraaten, Jan Abrahamsz.', 'alt_titles': ['Jan A. Beerstraaten', 'Johannes Abrahamsz. Beerstraaten'], 'birth_date': 1622, 'birth_place': None, 'death_date': 1666, 'death_place': None, 'description': None, 'is_licensing_restricted': None, 'is_artist': True, 'agent_type_title': 'Individual', 'agent_type_id': 7, 'artwork_ids': [83640], 'site_ids': [], 'last_updated_source': '1976-09-02T11:20:00-05:00', 'last_updated': '2019-05-14T15:19:43-05:00', 'timestamp': '2021-10-06T22:12:50-05:00'}, 'info': {'license_text': 'The data in this response is licensed under a Creative Commons Zero (CC0) 1.0 designation and the Terms and Conditions of artic.edu.', 'license_links': ['https://creativecommons.org/publicdomain/zero/1.0/', 'https://www.artic.edu/terms'], 'version': '1.1'}, 'config': {'iiif_url': 'https://www.artic.edu/iiif/2', 'website_url': 'http://www.artic.edu'}}, {'data': {'id': 1974, 'api_model': 'agents', 'api_link': 'https://api.artic.edu/api/v1/agents/1974', 'title': 'Sara Begody', 'sort_title': 'Begody, Sara', 'alt_titles': None, 'birth_date': None, 'birth_place': None, 'death_date': None, 'death_place': None, 'description': None, 'is_licensing_restricted': None, 'is_artist': True, 'agent_type_title': 'Individual', 'agent_type_id': 7, 'artwork_ids': [61009], 'site_ids': [], 'last_updated_source': '1976-09-02T11:20:00-05:00', 'last_updated': '2019-05-14T15:19:42-05:00', 'timestamp': '2021-10-06T22:13:29-05:00'}, 'info': {'license_text': 'The data in this response is licensed under a Creative Commons Zero (CC0) 1.0 designation and the Terms and Conditions of artic.edu.', 'license_links': ['https://creativecommons.org/publicdomain/zero/1.0/', 'https://www.artic.edu/terms'], 'version': '1.1'}, 'config': {'iiif_url': 'https://www.artic.edu/iiif/2', 'website_url': 'http://www.artic.edu'}}, {'data': {'id': 1992, 'api_model': 'agents', 'api_link': 'https://api.artic.edu/api/v1/agents/1992', 'title': 'Peter Behrens', 'sort_title': 'Behrens, Peter', 'alt_titles': None, 'birth_date': 1868, 'birth_place': None, 'death_date': 1940, 'death_place': None, 'description': None, 'is_licensing_restricted': None, 'is_artist': True, 'agent_type_title': 'Individual', 'agent_type_id': 7, 'artwork_ids': [29114, 121781, 120064, 109475], 'site_ids': [], 'suggest_autocomplete_all': {'input': ['Peter Behrens', 'Behrens, Peter'], 'weight': 2, 'contexts': {'groupings': ['title']}}, 'last_updated_source': '1976-09-02T11:20:00-05:00', 'last_updated': '2019-05-14T15:19:42-05:00', 'timestamp': '2021-10-06T22:14:03-05:00'}, 'info': {'license_text': 'The data in this response is licensed under a Creative Commons Zero (CC0) 1.0 designation and the Terms and Conditions of artic.edu.', 'license_links': ['https://creativecommons.org/publicdomain/zero/1.0/', 'https://www.artic.edu/terms'], 'version': '1.1'}, 'config': {'iiif_url': 'https://www.artic.edu/iiif/2', 'website_url': 'http://www.artic.edu'}}, {'data': {'id': 1998, 'api_model': 'agents', 'api_link': 'https://api.artic.edu/api/v1/agents/1998', 'title': 'Sadiqi', 'sort_title': 'Sadiqi', 'alt_titles': ['Sadiki Bek', 'Sadiq Beg', 'Sadiq Beg Afshar'], 'birth_date': 1533, 'birth_place': None, 'death_date': 1610, 'death_place': None, 'description': None, 'is_licensing_restricted': None, 'is_artist': True, 'agent_type_title': 'Individual', 'agent_type_id': 7, 'artwork_ids': [70594], 'site_ids': [], 'last_updated_source': '1976-09-02T11:20:00-05:00', 'last_updated': '2019-05-14T15:19:42-05:00', 'timestamp': '2021-10-06T22:14:36-05:00'}, 'info': {'license_text': 'The data in this response is licensed under a Creative Commons Zero (CC0) 1.0 designation and the Terms and Conditions of artic.edu.', 'license_links': ['https://creativecommons.org/publicdomain/zero/1.0/', 'https://www.artic.edu/terms'], 'version': '1.1'}, 'config': {'iiif_url': 'https://www.artic.edu ...

# %%
artwork_data=json_normalize(lista_2)
artwork_data
# Out:
#    data.id data.api_model                                data.api_link  \
# 0    83640       artworks  https://api.artic.edu/api/v1/artworks/83640
# 1    61009       artworks  https://api.artic.edu/api/v1/artworks/61009
# 2    29114       artworks  https://api.artic.edu/api/v1/artworks/29114
# 3    70594       artworks  https://api.artic.edu/api/v1/artworks/70594
# 4    54548       artworks  https://api.artic.edu/api/v1/artworks/54548
#
#    data.is_boosted                                         data.title  \
# 0            False                                      Gemear Castle
# 1            False  Rug or Wall Hanging in the "Two Grey Hills" Style
# 2            False                                           The Kiss
# 3            False                                     The Lion Tamer
# 4            False                                           Untitled
#
#   data.alt_titles                                data.thumbnail.lqip  \
# 0            None  ......
# 1            None  ......
# 2            None  ......
# 3            None  ......
# 4            None  ......
#
#    data.thumbnail.width  data.thumbnail.height  \
# 0                  3000                   1895
# 1                   930                   1332
# 2                  2296                   2970
# 3                  3000                   1989
# 4                  3000                   2980
#
#                              data.thumbnail.alt_text  ... data.site_ids  \
# 0              A work made of pen and wash on paper.  ...            []
# 1  A work made of wool, single interlocking tapes...  ...            []
# 2             A work made of color woodcut on paper.  ...            []
# 3              A work made of ink and gold on paper.  ...            []
# 4                  A work made of chromogenic print.  ...            []
#
#                        data.suggest_autocomplete_all  \
# 0  [{'input': ['1922.1690'], 'contexts': {'groupi...
# 1  [{'input': ['1980.689'], 'contexts': {'groupin...
# 2  [{'input': ['1968.187'], 'contexts': {'groupin...
# 3  [{'input': ['1987.360.5'], 'contexts': {'group...
# 4  [{'input': ['1978.1114.3'], 'contexts': {'grou...
#
#     data.last_updated_source          data.last_updated  \
# 0  2021-05-03T18:46:11-05:00  2021-05-21T11:00:47-05:00
# 1  2021-05-03T18:46:04-05:00  2021-05-04T08:35:45-05:00
# 2  2021-05-03T18:45:54-05:00  2021-05-04T11:27:13-05:00
# 3  2021-05-03T18:46:07-05:00  2021-05-21T12:28:15-05:00
# 4  2021-05-03T18:46:03-05:00  2021-05-24T15:52:52-05:00
#
#               data.timestamp  \
# 0  2021-10-06T22:15:52-05:00
# 1  2021-10-06T22:16:47-05:00
# 2  2021-10-06T22:17:42-05:00
# 3  2021-10-06T22:18:16-05:00
# 4  2021-10-06T22:18:47-05:00
#
#                                    info.license_text  \
# 0  The data in this response is licensed under a ...
# 1  The data in this response is licensed under a ...
# 2  The data in this response is licensed under a ...
# 3  The data in this response is licensed under a ...
# 4  The data in this response is licensed under a ...
#
#                                   info.license_links  info.version  \
# 0  [https://creativecommons.org/publicdomain/zero...           1.1
# 1  [https://creativecommons.org/publicdomain/zero...           1.1
# 2  [https://creativecommons.org/publicdomain/zero...           1.1
# 3  [https://creativecommons.org/publicdomain/zero...           1.1
# 4  [https://creativecommons.org/publicdomain/zero...           1.1
#
#                 config.iiif_url    config.website_url
# 0  https://www.artic.edu/iiif/2  http://www.artic.edu
# 1  https://www.artic.edu/iiif/2  http://www.artic.edu
# 2  https://www.artic.edu/iiif/2  http://www.artic.edu
# 3  https://www.artic.edu/iiif/2  http://www.artic.edu
# 4  https://www.artic.edu/iiif/2  http://www.artic.edu
#
# [5 rows x 104 columns]

# %%
artwork_data.columns
# Out:
# Index(['data.id', 'data.api_model', 'data.api_link', 'data.is_boosted',
#        'data.title', 'data.alt_titles', 'data.thumbnail.lqip',
#        'data.thumbnail.width', 'data.thumbnail.height',
#        'data.thumbnail.alt_text',
#        ...
#        'data.site_ids', 'data.suggest_autocomplete_all',
#        'data.last_updated_source', 'data.last_updated', 'data.timestamp',
#        'info.license_text', 'info.license_links', 'info.version',
#        'config.iiif_url', 'config.website_url'],
#       dtype='object', length=104)

# %%
artwork_data=artwork_data.rename(columns={'data.id': 'random_artwork_id'})
artwork_data=artwork_data.rename(columns={'data.title': 'title'})
artwork_data=artwork_data.rename(columns={'data.place_of_origin': 'place_of_origin'})
artwork_data=artwork_data.rename(columns={'data.material_titles': 'material_titles'})
artwork_data=artwork_data.rename(columns={'data.dimensions': 'dimensions'})
artwork_data=artwork_data.rename(columns={'data.artist_title': 'artist_title'})

# %%
main_artwork_data=artwork_data[['random_artwork_id','artist_title','title','place_of_origin','material_titles','dimensions']]
main_artwork_data
# Out:
#    random_artwork_id                 artist_title  \
# 0              83640  Jan Abrahamsz. Beerstraaten
# 1              61009                  Sara Begody
# 2              29114                Peter Behrens
# 3              70594                       Sadiqi
# 4              54548                  Janice Bell
#
#                                                title place_of_origin  \
# 0                                      Gemear Castle     Netherlands
# 1  Rug or Wall Hanging in the "Two Grey Hills" Style      New Mexico
# 2                                           The Kiss         Germany
# 3                                     The Lion Tamer            Iran
# 4                                           Untitled   United States
#
#                                      material_titles  \
# 0  [paper (fiber product), wash, coating (material)]
# 1                                   [wool (textile)]
# 2                            [paper (fiber product)]
# 3                 [paper (fiber product), gold, ink]
# 4                                                 []
#
#                                           dimensions
# 0                                               None
# 1               78.3 × 56.5 cm (30 3/4 × 22 1/4 in.)
# 2         270 × 215 mm (image); 370 × 280 mm (sheet)
# 3  Image: 13.8 × 19.6 cm (5 7/16 × 7 3/4 in.); \n...
# 4                                     21.6 × 21.6 cm

# %%
main_artwork_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   random_artwork_id  5 non-null      int64
#  1   artist_title       5 non-null      object
#  2   title              5 non-null      object
#  3   place_of_origin    5 non-null      object
#  4   material_titles    5 non-null      object
#  5   dimensions         4 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 368.0+ bytes

# %%
artists_and_artworks=artist_data.merge(main_artwork_data,how="left", on=['artist_title'])
artists_and_artworks
# Out:
#    artist_id                 artist_title               data.sort_title  \
# 0       1963  Jan Abrahamsz. Beerstraaten  Beerstraaten, Jan Abrahamsz.
# 1       1974                  Sara Begody                  Begody, Sara
# 2       1992                Peter Behrens                Behrens, Peter
# 3       1998                       Sadiqi                        Sadiqi
# 4       2006                  Janice Bell                  Bell, Janice
#
#    data.birth_date  data.death_date  data.is_artist data.agent_type_title  \
# 0           1622.0           1666.0            True            Individual
# 1              NaN              NaN            True            Individual
# 2           1868.0           1940.0            True            Individual
# 3           1533.0           1610.0            True            Individual
# 4              NaN              NaN            True            Individual
#
#         number_of_artworks_and_ids  random_artwork_id  \
# 0                          [83640]              83640
# 1                          [61009]              61009
# 2  [29114, 121781, 120064, 109475]              29114
# 3                          [70594]              70594
# 4                  [140958, 54548]              54548
#
#                                                title place_of_origin  \
# 0                                      Gemear Castle     Netherlands
# 1  Rug or Wall Hanging in the "Two Grey Hills" Style      New Mexico
# 2                                           The Kiss         Germany
# 3                                     The Lion Tamer            Iran
# 4                                           Untitled   United States
#
#                                      material_titles  \
# 0  [paper (fiber product), wash, coating (material)]
# 1                                   [wool (textile)]
# 2                            [paper (fiber product)]
# 3                 [paper (fiber product), gold, ink]
# 4                                                 []
#
#                                           dimensions
# 0                                               None
# 1               78.3 × 56.5 cm (30 3/4 × 22 1/4 in.)
# 2         270 × 215 mm (image); 370 × 280 mm (sheet)
# 3  Image: 13.8 × 19.6 cm (5 7/16 × 7 3/4 in.); \n...
# 4                                     21.6 × 21.6 cm

# %%
artists_and_artworks.to_csv('artists_and_artworks.csv')
